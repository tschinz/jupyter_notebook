# %% [markdown]
# # Mathjax Cheatsheet
# * [Mathjax Latest Documentation](docs.mathjax.org/en/latest/tex.html)
# * [Stack Exchange Basic Tutorial and Quick Reference](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference)
# * [List of LaTeX Mathematical Symbols](https://oeis.org/wiki/List_of_LaTeX_mathematical_symbols)
# * [List of LaTeX Symbols](https://latex.wikia.org/wiki/List_of_LaTeX_symbols)

# %% [markdown]
# ## Text & Additions
#
# | Latex Symbol               | Latex Code                 | Latex Symbol                 | Latex Code                   |
# | -------------------------- | -------------------------- | ---------------------------- | ---------------------------  |
# | $\text{normal text}$       | `\text{normal text}`       | $\textbf{bold text}$         | `\textbf{bold text}`         |
# | $\textit{italic text}$     | `\textit{italic text}`     | $\texttt{fixed spaced text}$ | `\texttt{fixed spaced text}` |
# | $Q_1$ $I_{min}$            | `Q_1 I_{min}`              | $x^2$ $x^{20}$               | `x^2 x^{20}`                 |
# | $\acute{x}$                | `\acute{x}`                | $\grave{x}$                  | `\grave{x}`                  |
# | $\dot{x}$                  | `\dot{x}`                  | $\ddot{x}$                   | `\ddot{x}`                   |
# | $\bar{x}$                  | `\bar{x}`                  | $\tilde{x}$                  | `\tilde{x}`                  |
# | $\hat{x}$                  | `\hat{x}`                  | $\check{x}$                  | `\check{x}`                  |
# | $\vec{x}$                  | `\vec{x}`                  | $\breve{x}$                  | `\breve{x}`                  |
# | $\overset{over}{X}$        | `\overset{over}{X}`        | $\underset{under}{X}$        | `\underset{under}{X}`        |
# | $\sideset{side}{}X$        | `\sideset{side}{}X`        | $\sideset{_1^2}{_3^4}X$      | `\sideset{_1^2}{_3^4}X`      |
# | $\overline{xxx}$           | `\overline{xxx}`           | $\underline{xxx}$            | `\underline{xxx}`            |
# | $\overbrace{xxx}$          | `\overbrace{xxx}`          | $\underbrace{xxx}$           | `\underbrace{xxx}`           |
# | $\overleftarrow{xxx}$      | `\overleftarrow{xxx}`      | $\overrightarrow{xxx}$       | `\overrightarrow{xxx}`       |
# | $\xleftarrow[under]{over}$ | `\xleftarrow[under]{over}` | $\xrightarrow[under]{over}$  | `\xrightarrow[under]{over}`  |

# %% [markdown]
# ## Spaces
#
# | Latex Symbol        | Latex Code          | Latex Symbol        | Latex Code           | Latex Symbol         | Latex Code           |
# | ------------------- | ------------------- | ------------------- | -------------------- | -------------------- | -------------------- |
# | $a \mspace{3mu} b$  | `a \mspace{3mu} b`  | $a \, b$            | `a \, b`             | $a \thinspace b$     | `a \thinspace b`     |
# | $a \mspace{4mu} b$  | `a \mspace{4mu} b`  | $a \:  b$           | `a \: b`             | $a \medspace b$      | `a \medspace b`      |
# | $a \mspace{5mu} b$  | `a \mspace{5mu} b`  | $a \; b$            | `a \; b`             | $a \thickspace b$    | `a \thickspace b`    |
# | $a \mspace{6mu} b$  | `a \mspace{6mu} b`  | $a \ b$             | `a \ b`              | -                    | -                    |
# | $a \mspace{18mu} b$ | `a \mspace{18mu} b` | $a \quad b$         | `a \quad b`          | -                    | -                    |
# | $a \mspace{36mu} b$ | `a \mspace{36mu} b` | $a \qquad b$        | `a \qquad b`         | -                    | -                    |
# | $a \mspace{-3mu} b$ | `a \mspace{-3mu} b` | $a \! b$            | `a \, b`             | $a \negthinspace b$  | `a \negthinspace b`  |
# | $a \mspace{-4mu} b$ | `a \mspace{-4mu} b` | -                   | -                    | $a \negmedspace b$   | `a \negmedspace b`   |
# | $a \mspace{-5mu} b$ | `a \mspace{-5mu} b` | -                   | -                    | $a \negthickspace b$ | `a \negthickspace b` |

# %% [markdown]
# ## Greek Letters
# | Latex Symbol                          | Latex Code |
# | ------------------------------------- | ---------- |
# | $A \alpha$                            | `A \alpha` |
# | $B \beta$                             | `B \beta` |
# | $\Gamma \gamma$                       | `\Gamma \gamma` |
# | $\Delta \delta$                       | `\Delta \delta` |
# | $E \epsilon \varepsilon $             | `E \epsilon \varepsilon ` |
# | $Z \zeta$                             | `Z \zeta` |
# | $H \eta$                              | `H \eta` |
# | $\Theta \theta \vartheta$             | `\Theta \theta \vartheta` |
# | $I \iota$                             | `I\iota` |
# | $K \kappa \varkappa$                  | `K \kappa \varkappa` |
# | $\Lambda \lambda$                     | `\Lambda \lambda` |
# | $M \mu$                               | `M \mu` |
# | $N \nu$                               | `N \nu` |
# | $\Xi \xi$                             | `\Xi \xi` |
# | $O \omicron$                          | `O \omicron` |
# | $\Pi \pi \varpi$                      | `\Pi \pi \varpi` |
# | $P \rho$                              | `P \rho` |
# | $\Sigma \sigma \varsigma$             | `\Sigma \sigma \varsigma` |
# | $T \tau$                              | `T \tau` |
# | $\Upsilon \upsilon$                   | `\Upsilon \upsilon` |
# | $\Phi \phi \varphi$                   | `\Phi \phi \varphi` |
# | $X \chi$                              | `X \chi` |
# | $\Psi \psi$                           | `\Psi \psi` |
# | $\Omega \omega$                       | `\Omega \omega` |

# %% [markdown]
# ## Symbols

# %% [markdown]
# ### Relation Operators
# | Latex Symbol                          | Latex Code    | Latex Symbol                          | Latex Code    |
# | ------------------------------------- | ------------- | ------------------------------------- | ------------- |
# | $<$                                   | `<`           | $>$                                   | `>` |
# | $\nless$                              | `\nless`      | $\ngtr$                               | `\ngtr` |
# | $\leq$                                | `\leq`        | $\geq$                                | `\geq` |
# | $\leqslant$                           | `\leqslant`   | $\geqslant$                           | `\geqslant` |
# | $\nleq$                               | `\nleq`       | $\ngeq$                               | `\ngeq` |
# | $\nleqslant$                          | `\nleqslant`  | $\ngeqslant$                          | `\ngeqslant` |
# | $\ll$                                 | `\ll`         | $gg$                                  | `gg` |
# | $\lll$                                | `\lll`        | $ggg$                                 | `ggg` |
# | $\subset$                             | `\subset`     | $\supset$                             | `\supset` |
# | $\not\subset$                         | `\not\subset` | $\not\supset$                         | `\not\supset` |
# | $\subseteq$                           | `\subseteq`   | $\supseteq$                           | `\supseteq` |
# | $\nsubseteq$                          | `\nsubseteq`  | $\nsupseteq$                          | `\nsupseteq` |
#
# | Latex Symbol                          | Latex Code |
# | ------------------------------------- | ---------- |
# | $=$                                   | `=` |
# | $\equiv$                              | `\equiv` |
# | $\approx$                             | `\approx` |
# | $\cong$                               | `\cong` |
# | $\simeq$                              | `\simeq` |
# | $\sim$                                | `\sim` |
# | $\propto$                             | `\propto` |
# | $\neq \ne$                            | `\neq \ne` |

# %% [markdown]
# ### Arrows
#
# | Latex Symbol                          | Latex Code        | Latex Symbol                          | Latex Code    |
# | ------------------------------------- | ----------------- | ------------------------------------- | ------------- |
# | $\rightarrow \to$                     | `\rightarrow \to` | $\leftarrow \gets$                    | `\leftarrow \gets` |
# | $\Rightarrow$                         | `\Rightarrow`     | $\Leftarrow$                          | `\Leftarrow` |
# | $\longrightarrow$                     | `\longrightarrow` | $\longrightarrow$                     | `\longrightarrow` |
# | $\Longrightarrow$                     | `\Longrightarrow` | $\Longrightarrow$                     | `\Longrightarrow` |
# | $\mapsto$                             | `\mapsto`         | -                                     | - |
# | $\longmapsto$                         | `\longmapsto`     | -                                     | - |
# | $\uparrow$                            | `\uparrow`        | $\Uparrow$                            | `\Uparrow` |
# | $\downarrow$                          | `\downarrow`      | $\Downarrow$                          | `\Downarrow` |
# | $\updownarrow$                        | `\updownarrow`    | $\Updownarrow$                        | `\Updownarrow` |

# %% [markdown]
# ### Boolsche Algebra Symbols
# | Operator        | Latex Symbol                           | Latex Code                  |
# | --------------- | -------------------------------------- | --------------------------- |
# | NEGATE          | $\neg \; \overline{x} \; \bar{x}$      | `\neg \overline{x} \bar{x}` |
# | AND             | $\bigwedge \; \wedge \; * \; \And$     | `\bigwedge \wedge * \And`   |
# | OR              | $\bigvee \; \vee \; + \; \mid$         | `\bigvee \vee + \mid`       |
# | XOR             | $\oplus$                               | `\oplus`                    |

# %% [markdown]
# ### Other Symbols
#
# | Latex Symbol    | Latex Code      | Latex Symbol         | Latex Code           | Latex Symbol      | Latex Code |
# | --------------- | --------------- | -------------------- | -------------------- | ----------------- | ---------- |
# | $\#$            | `\#`            | $\sharp$             | `\sharp`             | $\S$              | `\S` |
# | $\lozenge$      | `\lozenge`      | $\blacklozenge$      | `\blacklozenge`      | $\infty$          | `\infty` |
# | $\square$       | `\square`       | $\blacksquare$       | `\blacksquare`       | $\spadesuit$      | `\spadesuit` |
# | $\triangle$     | `\triangle`     | $\blacktriangle$     | `\blacktriangle`     | $\clubsuit$       | `\clubsuit` |
# | $\triangledown$ | `\triangledown` | $\blacktriangledown$ | `\blacktriangledown` | $\heartsuit$      | `\heartsuit` |
# | $\diagup$       | `\diagup`       | $\diagdown$          | `\diagdown`          | $\diamondsuit$    | `diamondsuit` |
# | $\varnothing$   | `\varnothing`   | $\emptyset$          | `\emptyset`          | $\angle$          | `\angle` |
# | $\square$       | `\square`       | $\surd$              | `\surd`              | $\measuredangle$  | `\measuredangle` |
# | $\prime$        | `\prime`        | $\blackprime$        | `\blackprime`        | $\sphericalangle$ | `\sphericalangle` |

# %% [markdown]
# ## Math Symbols

# %% [markdown]
# ### Trigonometry
# | Latex Symbol | Latex Code | Latex Symbol | Latex Code | Latex Symbol | Latex Code |
# | ------------ | ---------- | ------------ | ---------- | ------------ | ---------- |
# | $\sin$       | `\sin`     | $\arcsin$    | `\arcsin`  | $\sinh$      | `\sinh`    |
# | $\cos$       | `\cos`     | $\arccos$    | `\arccos`  | $\cosh$      | `\cosh`    |
# | $\tan$       | `\tan`     | $\arctan$    | `\arctan`  | $\tanh$      | `\tanh`    |
# | $\csc$       | `\csc`     | $\arccsc$    | `\arccsc`  | $\csch$      | `\csch`    |
# | $\sec$       | `\sec`     | $\arcsec$    | `\arcsec`  | $\sech$      | `\sech`    |
# | $\cot$       | `\cot`     | $\arccot$    | `\arccot`  | $\coth$      | `\coth`    |

# %% [markdown]
# ### Prefix Operators
# | Latex Symbol | Latex Code | Latex Symbol | Latex Code  | Latex Symbol | Latex Code   |
# | ------------ | ---------- | ------------ | ----------- | ------------ | ------------ |
# | $\int$       | `\int`     | $\oint$      | `\oint`     | $\sum$       | `\sum`       |
# | $\prod$      | `\prod`    | $\coprod$    | `\coprod`   | -            | -            |
# | $\bigodot$   | `\bigodot` | $\bigoplus$  | `\bigoplus` | $\bigotimes$ | `\bigotimes` |
# | $\bigcap$    | `\bigcap`  | $\bigcup$    | `\bigcup`   | $\bigsqcup$  | `\bigsqcup`  |
# | $\bigvee$    | `\bigvee`  | $\bigwedge$  | `\bigwedge` | -            | -            |

# %% [markdown]
# ## Arrays
#
# $$
# \begin{array}{c|l:cr}
#   n & \text{Left} & \text{Center} & \text{Right} \\ \hline
#   1 & 0.24 & 1 & 125 \\ \hdashline
#   2 & -1 & 189 & -8 \\
#   3 & -20 & 2000 & 1+10i \\
# \end{array}
# $$
#
# ```
# \begin{array}{c|l:cr}
#   n & \text{Left} & \text{Center} & \text{Right} \\ \hline
#   1 & 0.24 & 1 & 125 \\ \hdashline
#   2 & -1 & 189 & -8 \\
#   3 & -20 & 2000 & 1+10i \\
# \end{array}
# ```

# %% [markdown]
# ## Colors
# | Latex Symbol               | Latex Code                  |
# | -------------------------- | --------------------------- |
# | $\color{black}{black}$     | `\color{black}{black}`      |
# | $\color{grey}{grey}$       | `\color{grey}{grey}`        |
# | $\color{silver}{silver}$   | `\color{silver}{silver}`    |
# | $\color{white}{white}$     | `\color{white}{white}`      |
# | $\color{maroon}{maroon}$   | `\color{maroon}{maroon}`    |
# | $\color{red}{red}$         | `\color{red}{red}`          |
# | $\color{yellow}{yellow}$   | `\color{yellow}{yellow}`    |
# | $\color{lime}{lime}$       | `\color{lime}{lime}`        |
# | $\color{olive}{olive}$     | `\color{olive}{olive}`      |
# | $\color{green}{green}$     | `\color{green}{green}`      |
# | $\color{teal}{teal}$       | `\color{teal}{teal}`        |
# | $\color{aqua}{aqua}$       | `\color{aqua}{aqua}`        |
# | $\color{blue}{blue}$       | `\color{blue}{blue}`        |
# | $\color{navy}{navy}$       | `\color{navy}{navy}`        |
# | $\color{purple}{purple}$   | `\color{purple}{purple}`    |
# | $\color{fuchsia}{fuchsia}$ | `\color{fuschsia}{fuchsia}` |
#
# | Latex Symbol         | Latex Code           | Latex Symbol         | Latex Code           | Latex Symbol         | Latex Code           | Latex Symbol         | Latex Code           |
# | ---------------------| -------------------- | ---------------------| -------------------- | ---------------------| -------------------- | ---------------------| -------------------- |
# | $\color{#000}{text}$ | `\color{#000}{text}` | $\color{#005}{text}$ | `\color{#005}{text}` | $\color{#00A}{text}$ | `\color{#00A}{text}` | $\color{#00F}{text}$ | `\color{#00F}{text}` |
# | $\color{#500}{text}$ | `\color{#500}{text}` | $\color{#505}{text}$ | `\color{#505}{text}` | $\color{#50A}{text}$ | `\color{#50A}{text}` | $\color{#50F}{text}$ | `\color{#50F}{text}` |
# | $\color{#A00}{text}$ | `\color{#A00}{text}` | $\color{#A05}{text}$ | `\color{#A05}{text}` | $\color{#A0A}{text}$ | `\color{#A0A}{text}` | $\color{#A0F}{text}$ | `\color{#A0F}{text}` |
# | $\color{#F00}{text}$ | `\color{#F00}{text}` | $\color{#F05}{text}$ | `\color{#F05}{text}` | $\color{#F0A}{text}$ | `\color{#F0A}{text}` | $\color{#F0F}{text}$ | `\color{#F0F}{text}` |
# | $\color{#080}{text}$ | `\color{#080}{text}` | $\color{#085}{text}$ | `\color{#085}{text}` | $\color{#08A}{text}$ | `\color{#08A}{text}` | $\color{#08F}{text}$ | `\color{#08F}{text}` |
# | $\color{#580}{text}$ | `\color{#580}{text}` | $\color{#585}{text}$ | `\color{#585}{text}` | $\color{#58A}{text}$ | `\color{#58A}{text}` | $\color{#58F}{text}$ | `\color{#58F}{text}` |
# | $\color{#A80}{text}$ | `\color{#A80}{text}` | $\color{#A85}{text}$ | `\color{#A85}{text}` | $\color{#A8A}{text}$ | `\color{#A8A}{text}` | $\color{#A8F}{text}$ | `\color{#A8F}{text}` |
# | $\color{#F80}{text}$ | `\color{#F80}{text}` | $\color{#F85}{text}$ | `\color{#F85}{text}` | $\color{#F8A}{text}$ | `\color{#F8A}{text}` | $\color{#F8F}{text}$ | `\color{#F8F}{text}` |
# | $\color{#0A0}{text}$ | `\color{#0A0}{text}` | $\color{#0A5}{text}$ | `\color{#0A5}{text}` | $\color{#0AA}{text}$ | `\color{#0AA}{text}` | $\color{#0AF}{text}$ | `\color{#0AF}{text}` |
# | $\color{#5A0}{text}$ | `\color{#5A0}{text}` | $\color{#5A5}{text}$ | `\color{#5A5}{text}` | $\color{#5AA}{text}$ | `\color{#5AA}{text}` | $\color{#5AF}{text}$ | `\color{#5AF}{text}` |
# | $\color{#AA0}{text}$ | `\color{#AA0}{text}` | $\color{#AA5}{text}$ | `\color{#AA5}{text}` | $\color{#AAA}{text}$ | `\color{#AAA}{text}` | $\color{#AAF}{text}$ | `\color{#AAF}{text}` |
# | $\color{#FA0}{text}$ | `\color{#FA0}{text}` | $\color{#FA5}{text}$ | `\color{#FA5}{text}` | $\color{#FAA}{text}$ | `\color{#FAA}{text}` | $\color{#FAF}{text}$ | `\color{#FAF}{text}` |
# | $\color{#0F0}{text}$ | `\color{#0F0}{text}` | $\color{#0F5}{text}$ | `\color{#0F5}{text}` | $\color{#0FA}{text}$ | `\color{#0FA}{text}` | $\color{#0FF}{text}$ | `\color{#0FF}{text}` |
# | $\color{#5F0}{text}$ | `\color{#5F0}{text}` | $\color{#5F5}{text}$ | `\color{#5F5}{text}` | $\color{#5FA}{text}$ | `\color{#5FA}{text}` | $\color{#5FF}{text}$ | `\color{#5FF}{text}` |
# | $\color{#AF0}{text}$ | `\color{#AF0}{text}` | $\color{#AF5}{text}$ | `\color{#AF5}{text}` | $\color{#AFA}{text}$ | `\color{#AFA}{text}` | $\color{#AFF}{text}$ | `\color{#AFF}{text}` |
# | $\color{#FF0}{text}$ | `\color{#FF0}{text}` | $\color{#FF5}{text}$ | `\color{#FF5}{text}` | $\color{#FFA}{text}$ | `\color{#FFA}{text}` | $\color{#FFF}{text}$ | `\color{#FFF}{text}` |

# %% [markdown]
# ## Examples
#
# | Latex Symbol                                                                | Latex Code                                                           |
# | --------------------------------------------------------------------------- | -------------------------------------------------------------------- |
# | $$\sum_{i=0}^n i^2 = \frac{(n^2+n)(2n+1)}{6}$$                                | `\sum_{i=0}^n i^2 = \frac{(n^2+n)(2n+1)}{6}`                         |
# | $$
#     \begin{matrix}
#       1 & x & x^2 \\
#       1 & y & y^2 \\
#       1 & z & z^2 \\
#     \end{matrix}
#   $$                                                                           |  `\begin{matrix}
#                                                                                     1 & x & x^2 \\
#                                                                                     1 & y & y^2 \\
#                                                                                     1 & z & z^2 \\
#                                                                                   \end{matrix}`                                                      |
# | $$\begin{cases}
#       a_1x+b_1y+c_1z=d_1 \\
#       a_2x+b_2y+c_2z=d_2 \\
#       a_3x+b_3y+c_3z=d_3 \\
#     \end{cases}
#   $$                                                                          | `\begin{cases}
#                                                                                   a_1x+b_1y+c_1z=d_1 \\
#                                                                                    a_2x+b_2y+c_2z=d_2 \\
#                                                                                    a_3x+b_3y+c_3z=d_3
#                                                                                  \end{cases}`                                                        |
# | $$\bbox[yellow,5px,border:2px solid red]
#     { \\
#     e^x=\lim_{n\to\infty} \left( 1+\frac{x}{n} \right)^n \\
#     \qquad (1) \\
#   }
#   $$                                                                          | `\bbox[yellow,5px,border:2px solid red] { e^x=\lim_{n\to\infty} \left( 1+\frac{x}{n} \right)^n \qquad (1) }` |
# | $$\begin{align}
#     a &= b + c \tag{3}\label{eq3} \\
#     x &= yz \tag{4}\label{eq4}\\
#     l &= m - n \tag{5}\label{eq5}
#     \end{align}
#   $$                                                                          | `\begin{align}
#                                                                                   a &= b + c \tag{3}\label{eq3} \\
#                                                                                   x &= yz \tag{4}\label{eq4}\\
#                                                                                   l &= m - n \tag{5}\label{eq5}
#                                                                                   \end{align}`                                                       |
# | $$\begin{bmatrix}
#       1 & 2 & 2 \\
#       2 & 3 & 4 \\
#       4 & 4 & 2
#     \end{bmatrix} $$                                                          | `\begin{bmatrix}
#                                                                                   1 & 2 & 2 \\
#                                                                                   2 & 3 & 4 \\
#                                                                                   4 & 4 & 2
#                                                                                 \end{bmatrix}`                                                       |
# | $$\require{AMScd}
#   \begin{CD}
#       A @>a>> B\\
#       @V b V V= @VV c V\\
#       C @>>d> D
#   \end{CD}
#   $$                                                                          | `\require{AMScd} \begin{CD} A @>a>> B\\ @V b V V= @VV c V\\ C @>>d> D \end{CD}` |
