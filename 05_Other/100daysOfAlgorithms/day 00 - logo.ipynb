# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook

# %% [markdown]
# ## algorithm

# %%
xs, ys, cs = [], [], []

for x in range(0, 50):
    for y in range(0, 50):
        up = np.random.randint(0, 2)
        xs.append([x, x + .8])
        ys.append([y + .8 * (up >= .5), y + .8 * (up < .5)])

        col = np.random.randint(0, 4)
        cs.append({0: 'blue', 1: 'red', 2: 'white', 3: 'white'}[col])

# %% [markdown]
# ## plot

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="47cddcd0-720e-47e9-a2b2-a33bcad7b99b">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(plot_width=800, plot_height=800)

plot.grid.visible = False
plot.xaxis.visible = False
plot.yaxis.visible = False

plot.multi_line(xs, ys, color=cs, line_width=6, line_alpha=.1, line_cap='round')
plot.multi_line(xs, ys, color='black')

show(plot)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="94a3f3d3-e5c5-4a54-9ee9-0f47131f7d82"></div>
# </div>
